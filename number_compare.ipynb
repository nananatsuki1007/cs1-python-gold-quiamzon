# %% [markdown]
# <a href="https://colab.research.google.com/github/nananatsuki1007/cs1-python-gold-quiamzon/blob/main/number_compare.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num1 = int(input("enter the first number!! "))
num2 = int(input("enter the second number right now "))
num3 = int(input("enter the final number! "))

if num1 > num2 and num1 > num3:
  print("the first number is the largest!")
elif num2 > num1 and num2 > num3:
  print("the second number is the largest!!")
else:
  print("the third number is the largest!!!")
# Out:
# enter the first number!! 1
# enter the second number right now 2
# enter the final number! 3
# the third number is the largest!!!
