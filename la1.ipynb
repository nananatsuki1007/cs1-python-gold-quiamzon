# %% [markdown]
# <a href="https://colab.research.google.com/github/nananatsuki1007/cs1-python-gold-quiamzon/blob/main/la1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("Hello world!!!!! I am Tsukasa Tenma, a future star!!!!!!")
# Out:
# Hello world!!!!! I am Tsukasa Tenma, a future star!!!!!!
